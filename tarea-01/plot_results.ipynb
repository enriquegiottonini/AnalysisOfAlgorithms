# %%
x = [i*1000 for i in range(1, 11)]

# SELECTION SORT
selection_best = [0.007824,0.025799,0.051939,0.094820,0.170602,0.270770,0.284462,0.522975,0.673420,0.830803]
selection_worst = [0.007881,0.028041,0.059770,0.114162,0.163073,0.264626,0.320712,0.446152,0.560119,0.743811]
selection_average = [0.008779,0.026779,0.057631,0.096380,0.159569,0.217240,0.351367,0.473100,0.637975,0.811207]

# %%
import matplotlib.pyplot as plt

y = x**2
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
best = ax.scatter(x, selection_best, color='g')
avg = ax.scatter(x, selection_average, color='b')
worst = ax.scatter(x, selection_worst, color='r')
ax.legend((best, avg, worst), ("best", "average", "worst"))
ax.set_ylabel('Time taken in ms')
ax.set_xlabel('N')
ax.set_title('Selection Sort')
plt.plot(x, [xi**2 for xi in x])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 12
#      10 ax.set_xlabel('N')
#      11 ax.set_title('Selection Sort')
# ---> 12 plt.plot(x, x**2)
#      13 plt.show()
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'

# %%
# INSERTION SORT
insertion_best = [0.000039,0.000049,0.000094,0.000121,0.000167,0.000150,0.000210,0.000226,0.000241,0.000354]
insertion_worst = [0.008900,0.033794,0.071148,0.136728,0.230272,0.355639,0.500821,0.631154,0.836822,1.027353]
insertion_average = [0.004437,0.018812,0.038454,0.068145,0.104135,0.161154,0.250216,0.326638,0.416636,0.531528]

# %%
# MERGE SORT
merge_best = [0.002496,0.004930,0.007453,0.010541,0.012291,0.016619,0.019261,0.021358,0.022903,0.026250]
merge_worst = [0.002419,0.004925,0.008016,0.010229,0.012893,0.015237,0.019167,0.020427,0.022608,0.024473]
merge_average = [0.002659,0.005136,0.007878,0.013392,0.014277,0.015182,0.019800,0.021905,0.026572,0.027609]
